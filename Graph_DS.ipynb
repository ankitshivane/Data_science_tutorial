# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
r=np.random.randn(1000) ## generate random dataset

# %%
r
# Out:
# array([-3.33953447e-01, -3.77673428e-01,  1.12920894e-01, -1.30685677e+00,
#         9.92008389e-01, -3.08088351e-01, -5.79196940e-01, -2.95000103e-01,
#        -9.37228529e-01,  1.13264305e+00,  5.50330746e-01, -1.13857664e+00,
#        -6.22288232e-01,  1.35908015e+00,  1.08069473e+00,  3.52917594e-01,
#         1.19402061e-01,  3.33925226e-01, -5.74948047e-01, -1.16381954e+00,
#        -5.68953020e-01, -4.92437765e-01, -1.17833774e+00, -1.22200894e-01,
#         1.73815715e-01, -1.17918410e+00, -2.24059746e-01, -1.70931632e+00,
#        -6.75194867e-01, -8.35754998e-01, -1.31755034e+00,  2.45329492e+00,
#        -1.17571025e+00, -1.56600787e+00, -6.17437142e-01, -1.69830337e+00,
#        -5.65471402e-01,  8.42874929e-01,  9.64472835e-01,  8.08062530e-01,
#         5.64372288e-01, -4.16399232e-01,  1.23356549e+00, -1.01571912e+00,
#        -8.57401574e-01, -1.99745970e+00, -7.91782806e-01, -1.06020677e+00,
# ...

# %%
df=pd.DataFrame(r,columns=['data'],index=pd.date_range('2022/03/26',periods=1000))

# %%
r.shape
# Out:
# (1000,)

# %%
df
# Out:
#                 data
# 2022-03-26 -0.333953
# 2022-03-27 -0.377673
# 2022-03-28  0.112921
# 2022-03-29 -1.306857
# 2022-03-30  0.992008
# ...              ...
# 2024-12-15  0.860948
# 2024-12-16  0.439091
# 2024-12-17 -0.322924
# 2024-12-18  0.899220
# 2024-12-19  0.025319
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,10)) # set the size of the canvas
# Out:
# <AxesSubplot:>

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df=df.drop('Id',axis=1)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.head().plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa

# %%
df.iloc[5:6].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[[5]].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind='barh',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist',figsize=(20,10))  # here x axis is repesenting a range and y axis is representing a frequence
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['SepalLengthCm'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df['SepalLengthCm'].plot(kind='hist',orientation='horizontal') ## rotate the graph
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df.hist(figsize=(20,10),color='r') # change the color of a graph
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='g') # change the color of a graph
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='y',alpha=0.7) # change the color of a graph and alpha represent the color contrast
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',figsize=(20,10),color={'boxes':'g','whiskers':'r'})
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',figsize=(20,10),color={'boxes':'g','whiskers':'r'},vert=False)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',figsize=(20,10),stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',figsize=(20,10),stacked=True)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm') # try to use for comparison
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalWidthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm',c='SepalWidthCm',figsize=(20,10),s=300) # try to use for comparison
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm',c='SepalWidthCm',figsize=(20,10),s=df['PetalWidthCm']*100) # try to use for comparison
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x='SepalLengthCm',y='PetalLengthCm',figsize=(20,10),gridsize=30)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df1=df.iloc[0].drop('Species').plot(kind='pie') # first row fetch

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iloc[[0]]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa

# %%
df1=df.iloc[0].drop('Species').plot(kind='pie') # first row fetch

# %%
# !pip install plotly

# %%
# !pip install cufflinks
# Out:
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68734 sha256=cc6cdd80f1fcc1dc1f3de4832c24d083c990c80699266f1111a573003c3707d9
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# ...

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="29db27e9-b725-4070-9132-d27f2c641d5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iplot(x='SepalLengthCm',y='PetalLengthCm',mode='markers')
# Out:
# <div>                            <div id="3f556563-834a-4127-a1bd-792b8bff1cb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',mode='markers',size=5)
# Out:
# <div>                            <div id="d4a3743c-9b42-4d7b-a838-7b51feb2664c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble',x='SepalLengthCm',y='PetalLengthCm',size='SepalWidthCm')
# Out:
# <div>                            <div id="0d532857-8086-48e9-a1d8-1fcecb6d845c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="5afc155b-3829-4356-8c1f-77dad88f8931" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iplot(kind='scatter3d',x='SepalLengthCm',y='PetalLengthCm',z='SepalWidthCm')
# Out:
# <div>                            <div id="d2c47958-c4f3-4fa2-a3fe-b2dcb09ad4d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind='scatter3d',x='SepalLengthCm',y='PetalLengthCm',z='SepalWidthCm')
# Out:
# <div>                            <div id="b5018cb3-e289-4202-8937-4553c2faf6cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind='bubble3d',x='SepalLengthCm',y='PetalLengthCm',z='SepalWidthCm',size='SepalWidthCm')
# Out:
# <div>                            <div id="ba2bdda0-33d2-4ac7-b2f6-6bdb68aa66b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [raw]
# # Homework
# try to explore map graph and try to show and example (2-3)
